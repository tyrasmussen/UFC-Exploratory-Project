# %% [markdown]
# ## 6.1 Sourcing Open Data

# %% [markdown]
# ### This script will contain the following:
#
# #### Importing Libraries
# #### Import UFC Datasets
# #### Data Profiling
# #### Export Clean Dataframes

# %% [markdown]
# # 01. Import Libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Import UFC Datasets

# %%
# Path Creation
path = r'/Users/tyrasmussen/Desktop/08-2023 UFC Analysis'

# %%
# Import 'data' dataset
df_data = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'data.csv'))

# %%
# Import 'preprocessed_data' dataset
df_pre = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'preprocessed_data.csv'))

# %%
# Import 'raw_fighter_details' dataset
df_fighter = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'raw_fighter_details.csv'))

# %%
# Import 'raw_total_fight_data' dataset
df_fight_total = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'raw_total_fight_data.csv'))

# %% [markdown]
# # 03. Data Profiling

# %% [markdown]
# ## Data Shape

# %%
df_data.shape
# Out:
# (6012, 144)

# %%
df_pre.shape
# Out:
# (5902, 160)

# %%
df_fighter.shape
# Out:
# (3596, 14)

# %%
df_fight_total.shape
# Out:
# (6012, 44)

# %% [markdown]
# ## Data Check

# %%
df_data.head()
# Out:
#        R_fighter          B_fighter        Referee        date  \
# 0   Adrian Yanez      Gustavo Lopez  Chris Tognoni  2021-03-20
# 1   Trevin Giles      Roman Dolidze      Herb Dean  2021-03-20
# 2    Tai Tuivasa    Harry Hunsucker      Herb Dean  2021-03-20
# 3  Cheyanne Buys  Montserrat Conejo     Mark Smith  2021-03-20
# 4  Marion Reneau      Macy Chiasson     Mark Smith  2021-03-20
#
#                  location Winner  title_bout       weight_class  B_avg_KD  \
# 0  Las Vegas, Nevada, USA    Red       False       Bantamweight     0.000
# 1  Las Vegas, Nevada, USA    Red       False       Middleweight     0.500
# 2  Las Vegas, Nevada, USA    Red       False        Heavyweight       NaN
# 3  Las Vegas, Nevada, USA   Blue       False   WomenStrawweight       NaN
# 4  Las Vegas, Nevada, USA   Blue       False  WomenBantamweight     0.125
#
#    B_avg_opp_KD  ...  R_win_by_Decision_Unanimous  R_win_by_KO/TKO  \
# 0           0.0  ...                            0                1
# ...

# %%
df_pre.head()
# Out:
#   Winner  title_bout  B_avg_KD  B_avg_opp_KD  B_avg_SIG_STR_pct  \
# 0    Red       False  0.000000           0.0           0.420000
# 1    Red       False  0.500000           0.0           0.660000
# 2    Red       False  0.015625           0.0           0.450000
# 3   Blue       False  0.015625           0.0           0.450000
# 4   Blue       False  0.125000           0.0           0.535625
#
#    B_avg_opp_SIG_STR_pct  B_avg_TD_pct  B_avg_opp_TD_pct  B_avg_SUB_ATT  \
# 0                0.49500         0.330           0.36000       0.500000
# 1                0.30500         0.300           0.50000       1.500000
# 2                0.42750         0.250           0.20000       0.148468
# 3                0.42750         0.250           0.20000       0.148468
# 4                0.57875         0.185           0.16625       0.125000
#
#    B_avg_opp_SUB_ATT  ...  B_Stance_Open Stance  B_Stance_Orthodox  \
# 0           1.000000  ...                     0                  1
# ...

# %%
df_fighter.head()
# Out:
#           fighter_name  Height    Weight Reach    Stance           DOB  SLpM  \
# 0            Tom Aaron     NaN  155 lbs.   NaN       NaN  Jul 13, 1978  0.00
# 1           Papy Abedi  5' 11"  185 lbs.   NaN  Southpaw  Jun 30, 1978  2.80
# 2  Shamil Abdurakhimov   6' 3"  235 lbs.   76"  Orthodox  Sep 02, 1981  2.45
# 3         Danny Abbadi  5' 11"  155 lbs.   NaN  Orthodox  Jul 03, 1983  3.29
# 4         Hiroyuki Abe   5' 6"  145 lbs.   NaN  Orthodox           NaN  1.71
#
#   Str_Acc  SApM Str_Def  TD_Avg TD_Acc TD_Def  Sub_Avg
# 0      0%  0.00      0%    0.00     0%     0%      0.0
# 1     55%  3.15     48%    3.47    57%    50%      1.3
# 2     44%  2.45     58%    1.23    24%    47%      0.2
# 3     38%  4.41     57%    0.00     0%    77%      0.0
# 4     36%  3.11     63%    0.00     0%    33%      0.0

# %%
df_fight_total.head()
# Out:
#        R_fighter          B_fighter  R_KD  B_KD R_SIG_STR. B_SIG_STR.  \
# 0   Adrian Yanez      Gustavo Lopez     2     0  41 of 103   23 of 51
# 1   Trevin Giles      Roman Dolidze     0     0   27 of 57   32 of 67
# 2    Tai Tuivasa    Harry Hunsucker     1     0   14 of 18     2 of 6
# 3  Cheyanne Buys  Montserrat Conejo     0     0   31 of 65   15 of 41
# 4  Marion Reneau      Macy Chiasson     0     0   30 of 63  51 of 138
#
#   R_SIG_STR_pct B_SIG_STR_pct R_TOTAL_STR. B_TOTAL_STR.  ... last_round_time  \
# 0           39%           45%    41 of 103     23 of 51  ...            0:27
# 1           47%           47%     43 of 73    75 of 110  ...            5:00
# 2           77%           33%     14 of 18       2 of 6  ...            0:49
# 3           47%           36%     49 of 87   136 of 168  ...            5:00
# 4           47%           36%     59 of 93    92 of 184  ...            5:00
#
#           Format        Referee    date  Year       City    State  Country  \
# ...

# %%
df_data.columns
# Out:
# Index(['R_fighter', 'B_fighter', 'Referee', 'date', 'location', 'Winner',
#        'title_bout', 'weight_class', 'B_avg_KD', 'B_avg_opp_KD',
#        ...
#        'R_win_by_Decision_Unanimous', 'R_win_by_KO/TKO', 'R_win_by_Submission',
#        'R_win_by_TKO_Doctor_Stoppage', 'R_Stance', 'R_Height_cms',
#        'R_Reach_cms', 'R_Weight_lbs', 'B_age', 'R_age'],
#       dtype='object', length=144)

# %%
df_pre.columns
# Out:
# Index(['Winner', 'title_bout', 'B_avg_KD', 'B_avg_opp_KD', 'B_avg_SIG_STR_pct',
#        'B_avg_opp_SIG_STR_pct', 'B_avg_TD_pct', 'B_avg_opp_TD_pct',
#        'B_avg_SUB_ATT', 'B_avg_opp_SUB_ATT',
#        ...
#        'B_Stance_Open Stance', 'B_Stance_Orthodox', 'B_Stance_Sideways',
#        'B_Stance_Southpaw', 'B_Stance_Switch', 'R_Stance_Open Stance',
#        'R_Stance_Orthodox', 'R_Stance_Sideways', 'R_Stance_Southpaw',
#        'R_Stance_Switch'],
#       dtype='object', length=160)

# %%
df_fighter.columns
# Out:
# Index(['fighter_name', 'Height', 'Weight', 'Reach', 'Stance', 'DOB', 'SLpM',
#        'Str_Acc', 'SApM', 'Str_Def', 'TD_Avg', 'TD_Acc', 'TD_Def', 'Sub_Avg'],
#       dtype='object')

# %%
df_fight_total.columns
# Out:
# Index(['R_fighter', 'B_fighter', 'R_KD', 'B_KD', 'R_SIG_STR.', 'B_SIG_STR.',
#        'R_SIG_STR_pct', 'B_SIG_STR_pct', 'R_TOTAL_STR.', 'B_TOTAL_STR.',
#        'R_TD', 'B_TD', 'R_TD_pct', 'B_TD_pct', 'R_SUB_ATT', 'B_SUB_ATT',
#        'R_REV', 'B_REV', 'R_CTRL', 'B_CTRL', 'R_HEAD', 'B_HEAD', 'R_BODY',
#        'B_BODY', 'R_LEG', 'B_LEG', 'R_DISTANCE', 'B_DISTANCE', 'R_CLINCH',
#        'B_CLINCH', 'R_GROUND', 'B_GROUND', 'win_by', 'last_round',
#        'last_round_time', 'Format', 'Referee', 'date', 'Year', 'City', 'State',
#        'Country', 'Fight_type', 'Winner'],
#       dtype='object')

# %%
df_data.describe()
# Out:
#           B_avg_KD  B_avg_opp_KD  B_avg_SIG_STR_pct  B_avg_opp_SIG_STR_pct  \
# count  4585.000000   4585.000000        4585.000000            4585.000000
# mean      0.247476      0.176818           0.453310               0.434290
# std       0.378509      0.324633           0.130458               0.132618
# min       0.000000      0.000000           0.000000               0.000000
# 25%       0.000000      0.000000           0.376489               0.351045
# 50%       0.015625      0.000000           0.450000               0.427500
# 75%       0.500000      0.250000           0.527500               0.510000
# max       5.000000      3.000000           1.000000               1.000000
#
#        B_avg_TD_pct  B_avg_opp_TD_pct  B_avg_SUB_ATT  B_avg_opp_SUB_ATT  \
# count   4585.000000       4585.000000    4585.000000        4585.000000
# mean       0.292650          0.268742       0.478884           0.409276
# std        0.273628          0.267178       0.724229           0.653826
# ...

# %%
df_pre.describe()
# Out:
#           B_avg_KD  B_avg_opp_KD  B_avg_SIG_STR_pct  B_avg_opp_SIG_STR_pct  \
# count  5902.000000   5902.000000        5902.000000            5902.000000
# mean      0.193739      0.135246           0.452788               0.432788
# std       0.346475      0.294238           0.114325               0.116189
# min       0.000000      0.000000           0.000000               0.000000
# 25%       0.000000      0.000000           0.401611               0.376250
# 50%       0.015625      0.000000           0.450000               0.427500
# 75%       0.250000      0.093750           0.500000               0.480000
# max       5.000000      3.000000           1.000000               1.000000
#
#        B_avg_TD_pct  B_avg_opp_TD_pct  B_avg_SUB_ATT  B_avg_opp_SUB_ATT  \
# count   5902.000000       5902.000000    5902.000000        5902.000000
# mean       0.282610          0.252897       0.400956           0.335873
# std        0.239811          0.235253       0.648117           0.586483
# ...

# %%
df_fighter.describe()
# Out:
#               SLpM         SApM       TD_Avg      Sub_Avg
# count  3596.000000  3596.000000  3596.000000  3596.000000
# mean      2.279633     2.982948     1.211243     0.636707
# std       1.901956     2.814008     1.914020     1.566843
# min       0.000000     0.000000     0.000000     0.000000
# 25%       0.700000     1.400000     0.000000     0.000000
# 50%       2.170000     2.760000     0.510000     0.000000
# 75%       3.420000     4.002500     1.885000     0.800000
# max      19.910000    52.500000    32.140000    21.900000

# %%
df_fight_total.describe()
# Out:
#               R_KD         B_KD    R_SUB_ATT    B_SUB_ATT        R_REV  \
# count  6012.000000  6012.000000  6012.000000  6012.000000  6012.000000
# mean      0.249834     0.179807     0.481371     0.343979     0.137725
# std       0.523408     0.456132     0.924078     0.791808     0.422296
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       0.000000     0.000000     1.000000     0.000000     0.000000
# max       5.000000     4.000000    10.000000     7.000000     5.000000
#
#              B_REV   last_round         Year
# count  6012.000000  6012.000000  6012.000000
# mean      0.135396     2.316700  2013.381238
# std       0.414708     1.008284     5.572919
# min       0.000000     1.000000  1994.000000
# 25%       0.000000     1.000000  2011.000000
# 50%       0.000000     3.000000  2014.000000
# ...

# %% [markdown]
# ## Check Data Quality

# %% [markdown]
# ## Duplicates

# %%
data_dups = df_data[df_data.duplicated()]

# %%
data_dups
# Out:
# Empty DataFrame
# ...

# %%
pre_dups = df_pre[df_pre.duplicated()]

# %%
pre_dups
# Out:
# Empty DataFrame
# ...

# %%
fighter_dups = df_fighter[df_fighter.duplicated()]

# %%
fighter_dups
# Out:
# Empty DataFrame
# Columns: [fighter_name, Height, Weight, Reach, Stance, DOB, SLpM, Str_Acc, SApM, Str_Def, TD_Avg, TD_Acc, TD_Def, Sub_Avg]
# Index: []

# %%
fight_total_dups = df_fight_total[df_fight_total.duplicated()]

# %%
fight_total_dups
# Out:
# Empty DataFrame
# Columns: [R_fighter, B_fighter, R_KD, B_KD, R_SIG_STR., B_SIG_STR., R_SIG_STR_pct, B_SIG_STR_pct, R_TOTAL_STR., B_TOTAL_STR., R_TD, B_TD, R_TD_pct, B_TD_pct, R_SUB_ATT, B_SUB_ATT, R_REV, B_REV, R_CTRL, B_CTRL, R_HEAD, B_HEAD, R_BODY, B_BODY, R_LEG, B_LEG, R_DISTANCE, B_DISTANCE, R_CLINCH, B_CLINCH, R_GROUND, B_GROUND, win_by, last_round, last_round_time, Format, Referee, date, Year, City, State, Country, Fight_type, Winner]
# Index: []
#
# [0 rows x 44 columns]

# %% [markdown]
# ## Missing Data

# %%
pd.options.display.max_rows = None

# %%
df_data.isnull().sum()
# Out:
# R_fighter                          0
# B_fighter                          0
# Referee                           32
# date                               0
# location                           0
# Winner                             0
# title_bout                         0
# weight_class                       0
# B_avg_KD                        1427
# B_avg_opp_KD                    1427
# B_avg_SIG_STR_pct               1427
# B_avg_opp_SIG_STR_pct           1427
# B_avg_TD_pct                    1427
# B_avg_opp_TD_pct                1427
# B_avg_SUB_ATT                   1427
# B_avg_opp_SUB_ATT               1427
# B_avg_REV                       1427
# B_avg_opp_REV                   1427
# B_avg_SIG_STR_att               1427
# B_avg_SIG_STR_landed            1427
# B_avg_opp_SIG_STR_att           1427
# B_avg_opp_SIG_STR_landed        1427
# B_avg_TOTAL_STR_att             1427
# B_avg_TOTAL_STR_landed          1427
# B_avg_opp_TOTAL_STR_att         1427
# ...

# %%
df_data.dropna(inplace = True)

# %%
df_data.isnull().sum()
# Out:
# R_fighter                       0
# B_fighter                       0
# Referee                         0
# date                            0
# location                        0
# Winner                          0
# title_bout                      0
# weight_class                    0
# B_avg_KD                        0
# B_avg_opp_KD                    0
# B_avg_SIG_STR_pct               0
# B_avg_opp_SIG_STR_pct           0
# B_avg_TD_pct                    0
# B_avg_opp_TD_pct                0
# B_avg_SUB_ATT                   0
# B_avg_opp_SUB_ATT               0
# B_avg_REV                       0
# B_avg_opp_REV                   0
# B_avg_SIG_STR_att               0
# B_avg_SIG_STR_landed            0
# B_avg_opp_SIG_STR_att           0
# B_avg_opp_SIG_STR_landed        0
# B_avg_TOTAL_STR_att             0
# B_avg_TOTAL_STR_landed          0
# B_avg_opp_TOTAL_STR_att         0
# B_avg_opp_TOTAL_STR_landed      0
# B_avg_TD_att                    0
# ...

# %%
df_pre.isnull().sum()
# Out:
# Winner                             0
# title_bout                         0
# B_avg_KD                           0
# B_avg_opp_KD                       0
# B_avg_SIG_STR_pct                  0
# B_avg_opp_SIG_STR_pct              0
# B_avg_TD_pct                       0
# B_avg_opp_TD_pct                   0
# B_avg_SUB_ATT                      0
# B_avg_opp_SUB_ATT                  0
# B_avg_REV                          0
# B_avg_opp_REV                      0
# B_avg_SIG_STR_att                  0
# B_avg_SIG_STR_landed               0
# B_avg_opp_SIG_STR_att              0
# B_avg_opp_SIG_STR_landed           0
# B_avg_TOTAL_STR_att                0
# B_avg_TOTAL_STR_landed             0
# B_avg_opp_TOTAL_STR_att            0
# B_avg_opp_TOTAL_STR_landed         0
# B_avg_TD_att                       0
# B_avg_TD_landed                    0
# B_avg_opp_TD_att                   0
# B_avg_opp_TD_landed                0
# B_avg_HEAD_att                     0
# ...

# %%
df_fighter.isnull().sum()
# Out:
# fighter_name       0
# Height           263
# Weight            74
# Reach           1912
# Stance           804
# DOB              739
# SLpM               0
# Str_Acc            0
# SApM               0
# Str_Def            0
# TD_Avg             0
# TD_Acc             0
# TD_Def             0
# Sub_Avg            0
# dtype: int64

# %%
df_fighter.dropna(inplace = True)

# %%
df_fighter.isnull().sum()
# Out:
# fighter_name    0
# Height          0
# Weight          0
# Reach           0
# Stance          0
# DOB             0
# SLpM            0
# Str_Acc         0
# SApM            0
# Str_Def         0
# TD_Avg          0
# TD_Acc          0
# TD_Def          0
# Sub_Avg         0
# dtype: int64

# %%
df_fight_total.isnull().sum()
# Out:
# R_fighter            0
# B_fighter            0
# R_KD                 0
# B_KD                 0
# R_SIG_STR.           0
# B_SIG_STR.           0
# R_SIG_STR_pct        0
# B_SIG_STR_pct        0
# R_TOTAL_STR.         0
# B_TOTAL_STR.         0
# R_TD                 0
# B_TD                 0
# R_TD_pct             0
# B_TD_pct             0
# R_SUB_ATT            0
# B_SUB_ATT            0
# R_REV                0
# B_REV                0
# R_CTRL               0
# B_CTRL               0
# R_HEAD               0
# B_HEAD               0
# R_BODY               0
# B_BODY               0
# R_LEG                0
# B_LEG                0
# R_DISTANCE           0
# B_DISTANCE           0
# R_CLINCH             0
# B_CLINCH             0
# R_GROUND             0
# B_GROUND             0
# win_by               0
# last_round           0
# last_round_time      0
# Format               0
# Referee             32
# date                 0
# Year                 0
# City                 0
# ...

# %%
df_fight_total.dropna(inplace = True)

# %%
df_fight_total.isnull().sum()
# Out:
# R_fighter          0
# B_fighter          0
# R_KD               0
# B_KD               0
# R_SIG_STR.         0
# B_SIG_STR.         0
# R_SIG_STR_pct      0
# B_SIG_STR_pct      0
# R_TOTAL_STR.       0
# B_TOTAL_STR.       0
# R_TD               0
# B_TD               0
# R_TD_pct           0
# B_TD_pct           0
# R_SUB_ATT          0
# B_SUB_ATT          0
# R_REV              0
# B_REV              0
# R_CTRL             0
# B_CTRL             0
# R_HEAD             0
# B_HEAD             0
# R_BODY             0
# B_BODY             0
# R_LEG              0
# B_LEG              0
# R_DISTANCE         0
# B_DISTANCE         0
# R_CLINCH           0
# B_CLINCH           0
# R_GROUND           0
# B_GROUND           0
# win_by             0
# last_round         0
# last_round_time    0
# Format             0
# Referee            0
# date               0
# Year               0
# City               0
# State              0
# Country            0
# Fight_type         0
# ...

# %% [markdown]
# ## Check shape of clean dataframes

# %%
df_data.shape
# Out:
# (3890, 144)

# %%
df_pre.shape
# Out:
# (5902, 160)

# %%
df_fighter.shape
# Out:
# (1661, 14)

# %%
df_fight_total.shape
# Out:
# (5368, 44)

# %% [markdown]
# # 04. Export Clean Dataframes

# %%
# Export data to pkl
df_data.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'data.pkl'))

# %%
# Export data to pkl
df_pre.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'pre.pkl'))

# %%
# Export data to pkl
df_fighter.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'fighter'))

# %%
# Export data to pkl
df_fight_total.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'fight_total'))
